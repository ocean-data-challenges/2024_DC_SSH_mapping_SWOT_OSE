# %% [markdown]
# # Assessing the Integration of Wide-Swath Karin Data into a 6 Nadir Altimeter Sea Surface Gridded Product
#
# <div style="text-align: right"><i> 2024-05-20 INTERCOMPARISON_DEMO </i></div>
#
# ***
# **Authors:**  CLS <br>
# **Copyright:** 2024 CLS <br>
# **License:** MIT
#
# <div class="alert alert-block alert-success">
# <h1><center Intercomparison of sea surface height maps</center></h1>
# <h5> The notebook aims to evaluate the sea surface height maps produced by the MIOST system. </h5>
#     <h5> These maps are equivalent to the SEALEVEL_GLO_PHY_L4_MY_008_047 product distributed by the Copernicus Marine Service, except that a nadir altimeter (SARAL/Altika, SEALEVEL_GLO_PHY_L3_MY_008_062 product) has been excluded from the mapping. </h5>
#         <h5> We provide below a demonstration of the validation of these maps against the independent SSH data from the Saral/AltiKa altimeter distributed by CMEMS </h5>
# </div>

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***
#
#
# <div class="alert alert-danger" role="alert">
#
# <h3>Learning outcomes</h3>
#
# At the end of this notebook you will know the impact of wide swath KaRin data into 6 nadir altimeter SSH mapping
#
# </div>

# %%
import sys
sys.path.append('..')
from src.mod_plot import *
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b3680222-9f07-4d46-b139-1ac202f8bd76" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>1. Reference maps: MIOST sea surface products from 6 nadirs altimeters</h2>
#
# </div>

# %%
output_dir = './results'
miost_6nadirs_stat_filename = f'{output_dir}/stat_mapping_miost_c2n_h2b_j3n_s3a_s3b_s6a-hr.nc'
miost_6nadirs_psd_filename = f'{output_dir}/psd_mapping_miost_c2n_h2b_j3n_s3a_s3b_s6a-hr.nc'

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>2. Experimental maps: MIOST sea surface products from 6 nadirs + 1 Karin altimeters</h2>
#
# </div>

# %%
miost_6nadirs_1swot_stat_filename = f'{output_dir}/stat_mapping_miost_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'
miost_6nadirs_1swot_psd_filename = f'{output_dir}/psd_mapping_miost_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h2>3. Contribution of Karin into a 6 nadirs altimeter constellation</h2>
# </div>

# %%
# Plot gridded stats
# Hvplot
# compare_stat_score_map(miost_geos_stat_filename, duacs_geos_stat_filename)
# Matplotlib
compare_stat_score_map_png(miost_6nadirs_1swot_stat_filename, miost_6nadirs_stat_filename)

# %%
#compare_psd_score(miost_geos_psd_filename, duacs_geos_psd_filename)
compare_psd_score_png(miost_6nadirs_1swot_psd_filename, miost_6nadirs_psd_filename)
