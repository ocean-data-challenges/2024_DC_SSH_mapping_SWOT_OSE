# %% [markdown]
# # Intercomparing 4DvarNET and MIOST Altimeter Sea Surface Gridded Product
#
# <div style="text-align: right"><i> 2024-05-20 INTERCOMPARISON_DEMO </i></div>
#
# ***
# **Authors:**  CLS <br>
# **Copyright:** 2024 CLS <br>
# **License:** MIT

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***
#
#
# <div class="alert alert-danger" role="alert">
#
# <h3>Learning outcomes</h3>
#
# At the end of this notebook you will know the impact of wide swath KaRin data into 6 nadir altimeter SSH mapping
#
# </div>

# %%
import sys
sys.path.append('..')
from src.mod_plot import *
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>1. Reference maps: MIOST sea surface products from 6 nadirs altimeters + 1 Karin altimeters</h2>
#
# </div>

# %%
output_dir = './results'
miost_6nadirs_1swot_stat_filename = f'{output_dir}/stat_mapping_miost_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'
miost_6nadirs_1swot_psd_filename = f'{output_dir}/psd_mapping_miost_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>2. Experimental maps: 4DvarNET sea surface products from 6 nadirs + 1 Karin altimeters</h2>
#
# </div>

# %%
fourdvarnet_6nadirs_1swot_stat_filename = f'{output_dir}/stat_mapping_4dvarnet_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'
fourdvarnet_6nadirs_1swot_psd_filename = f'{output_dir}/psd_mapping_4dvarnet_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h2>3. Mapping 4DvarNET vs MIOST</h2>
# </div>

# %% [markdown]
# #### Statistical maps

# %%
compare_stat_score_map_png(fourdvarnet_6nadirs_1swot_stat_filename, miost_6nadirs_1swot_stat_filename)

# %% [markdown]
# #### Effective resolution

# %%
compare_psd_score_png(fourdvarnet_6nadirs_1swot_psd_filename, miost_6nadirs_1swot_psd_filename)

# %% [markdown]
# #### Statistic by oceanic regimes
# The figure below shows the mask used for the different oceanic regimes considered.
# <p align="center">
#   <img src="../figures/oceanic_regime.png" alt="Alt Text" width="600"/>
# </p>
# <p align="center">

# %%
plot_diff_stat_by_regimes(fourdvarnet_6nadirs_1swot_stat_filename, miost_6nadirs_1swot_stat_filename)
# Out:
#                   Δmapping_err_var [cm²]  Δmapping_err_var [%]  \
# coastal                        -0.032197             -0.111561
# offshore_highvar                6.646129             30.687066
# offshore_lowvar                 0.910144              8.451988
# equatorial_band                 1.156462             10.937358
# arctic                          1.059170              3.400018
# antarctic                     -15.769130            -29.316910
#
#                   Δmapping_err_filtered_var [cm²]  \
# coastal                                  0.002658
# offshore_highvar                         0.712740
# offshore_lowvar                          0.124280
# equatorial_band                          0.217667
# arctic                                  -0.025329
# antarctic                               -0.085297
#
#                   Δmapping_err_filtered_var [%]
# coastal                                0.119130
# offshore_highvar                      24.122593
# ...
