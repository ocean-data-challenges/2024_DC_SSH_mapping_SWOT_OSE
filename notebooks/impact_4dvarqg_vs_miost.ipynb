# %% [markdown]
# # Intercomparing 4DvarQG and MIOST Altimeter Sea Surface Gridded Product
#
# <div style="text-align: right"><i> 2024-05-20 INTERCOMPARISON_DEMO </i></div>
#
# ***
# **Authors:**  CLS <br>
# **Copyright:** 2024 CLS <br>
# **License:** MIT

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***
#
#
# <div class="alert alert-danger" role="alert">
#
# <h3>Learning outcomes</h3>
#
# At the end of this notebook you will know the impact of wide swath KaRin data into 6 nadir altimeter SSH mapping
#
# </div>

# %%
import sys
sys.path.append('..')
from src.mod_plot import *
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>1. Reference maps: MIOST sea surface products from 6 nadirs altimeters + 1 Karin altimeters</h2>
#
# </div>

# %%
output_dir = './results'
miost_6nadirs_1swot_stat_filename = f'{output_dir}/stat_mapping_miost_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'
miost_6nadirs_1swot_psd_filename = f'{output_dir}/psd_mapping_miost_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>2. Experimental maps: 4DvarQG sea surface products from 6 nadirs + 1 Karin altimeters</h2>
#
# </div>

# %%
fourdvarqg_6nadirs_1swot_stat_filename = f'{output_dir}/stat_mapping_4dvarqg_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'
fourdvarqg_6nadirs_1swot_psd_filename = f'{output_dir}/psd_mapping_4dvarqg_c2n_h2b_j3n_s3a_s3b_s6a-hr_swot.nc'

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h2>3. Mapping 4DvarQG vs MIOST</h2>
# </div>

# %% [markdown]
# #### Statistical maps

# %%
compare_stat_score_map_png(fourdvarqg_6nadirs_1swot_stat_filename, miost_6nadirs_1swot_stat_filename)

# %% [markdown]
# #### Effective resolution

# %%
compare_psd_score_png(fourdvarqg_6nadirs_1swot_psd_filename, miost_6nadirs_1swot_psd_filename)

# %% [markdown]
# #### Statistic by oceanic regimes
# The figure below shows the mask used for the different oceanic regimes considered.
# <p align="center">
#   <img src="../figures/oceanic_regime.png" alt="Alt Text" width="600"/>
# </p>
# <p align="center">

# %%
plot_diff_stat_by_regimes(fourdvarqg_6nadirs_1swot_stat_filename, miost_6nadirs_1swot_stat_filename)
# Out:
#                   Δmapping_err_var [cm²]  Δmapping_err_var [%]  \
# coastal                        -9.987527            -34.606461
# offshore_highvar                0.709937              3.277980
# offshore_lowvar                 1.180798             10.965401
# equatorial_band                      NaN                   NaN
# arctic                               NaN                   NaN
# antarctic                            NaN                   NaN
#
#                   Δmapping_err_filtered_var [cm²]  \
# coastal                                 -0.672634
# offshore_highvar                        -0.348587
# offshore_lowvar                         -0.035252
# equatorial_band                               NaN
# arctic                                        NaN
# antarctic                                     NaN
#
#                   Δmapping_err_filtered_var [%]
# coastal                              -30.143360
# offshore_highvar                     -11.797885
# ...
